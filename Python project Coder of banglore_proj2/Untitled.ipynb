# %%
with open("finaldata.txt", encoding = 'Utf-8') as f:
    data = f.read()
data
# Out:
# "techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes\n\nblrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes\n\nhsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com\n\ncloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud\n\nkoramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter\n\nai_bangalore_news\n1,340 posts\n38K followers\n200 following\nAI Bangalore\nMedia\n🤖 Daily AI news from India\n📢 Startup & resea
# ...

# %% [markdown]
# The next step is to break the data into individual profile blocks. Each profile in the file is separated by two newline characters, so splitting on that pattern gives us separate units to work with.

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(c) > 3]
chunks
# Out:
# ['techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes',
#  'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes',
#  'hsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com',
#  'cloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud',
#  'koramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter',
# ...

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(c) > 3]
chunks
# Out:
# ['techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes',
#  'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes',
#  'hsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com',
#  'cloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud',
#  'koramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter',
# ...

# %% [markdown]
# At this point, the list contains one chunk per profile. To examine a single profile and better understand the format, we can print an element such as:

# %%
chunks[4]
# Out:
# 'koramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter'

# %% [markdown]
# This helps us see the structure of each block before writing the parsing logic.
#
# The goal is to convert each chunk from raw text into a clean Python dictionary. For that, we define a function that trims extra whitespace, separates the lines, removes labels, and returns the meaningful parts.

# %%
def parse_chunk(chunks): 
        chunk = chunks.strip()
        lines = chunks.split("\n")
        name = lines[0].replace("Name: ", "")
        posts = lines[1].replace("Posts: ", "")
        followers = lines[2].replace("Followers: ", "")
        bio = lines[3].replace("Bio: ", "")
        
        return {"name": name, "posts": posts, "followers": followers, "bio": bio}
hello = chunks[0]
parse_chunk(hello)
# Out:
# {'name': 'techie_koramangala',
#  'posts': '420 posts',
#  'followers': '9,800 followers',
#  'bio': '310 following'}

# %% [markdown]
# Running the function on a sample chunk gives a structured dictionary containing the name, posts, followers and bio fields extracted from the original text.
#
# So far, we have a stable method to read demo data from a file, split it into separate profile blocks, and parse each block into a structured format using only basic Python. This sets up the foundation for the next step.

# %%
def parse_chunk(chunk):
    # print(chunk)
    chunk = chunk.strip()
    sep_chunk = chunk.split('\n')
    username = sep_chunk[0]
    no_of_posts = sep_chunk[1]
    no_of_followers = sep_chunk[2]
    no_of_following = sep_chunk[3]
    name = sep_chunk[4]

    if(len(sep_chunk) > 5):
        type_of_page = sep_chunk[5]
        bio = "\n".join(sep_chunk[6:])
    else:
        type_of_page = "Unknown"
        bio = ""

    # print(username, no_of_posts, no_of_followers, no_of_following, name, type_of_page, bio, sep="\n")

    return {
        "username": username,
        "no_of_posts": no_of_posts,
        "no_of_followers": no_of_followers,
        "no_of_following": no_of_following,
        "name": name,
        "type_of_page": type_of_page,
        "bio": bio
        }

# %%
all_chunks = []
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)

# print(all_chunks)
import json

s = json.dumps(all_chunks, indent=4)
print(s)
# Out:
# [
#     {
#         "username": "techie_koramangala",
#         "no_of_posts": "420 posts",
#         "no_of_followers": "9,800 followers",
#         "no_of_following": "310 following",
#         "name": "Arjun M.",
#         "type_of_page": "Software Engineer",
#         "bio": "\ud83d\udcbb Full-stack @ SaaS startup\n\u2615 Working from cafes in Koramangala\ngithub.com/arjunmakes"
#     },
#     {
#         "username": "blrcoder_girl",
#         "no_of_posts": "150 posts",
#         "no_of_followers": "6,300 followers",
#         "no_of_following": "120 following",
#         "name": "Riya Codes",
#         "type_of_page": "Tech Creator",
#         "bio": "\ud83d\udc69\u200d\ud83d\udcbb Python | ML | Roadmaps\n\ud83c\udfa5 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes"
#     },
#     {
#         "username": "hsr_startup_stories",
#         "no_of_posts": "980 posts",
#         "no_of_followers": "22.4K followers",
#         "no_of_following": "95 following",
# ...

# %%
def parse_chunk(chunk):
    chunk = chunk.strip()
    sep_chunk = chunk.split('\n')
    username = sep_chunk[0]
    
    no_of_posts = int(sep_chunk[1].split(' post')[0].replace(',', ''))
    
    no_of_followers = float(sep_chunk[2].split(' follower')[0].replace(',', '').replace('K', '').replace('M', ''))
    if('K' in sep_chunk[2]):
        no_of_followers = int(no_of_followers * 1000)
    elif('M' in sep_chunk[2]):
        no_of_followers = int(no_of_followers * 1000000)
    else:
        no_of_followers = int(no_of_followers)
    
    
    no_of_following = float(sep_chunk[3].split(' following')[0].replace(',', '').replace('K', '').replace('M', ''))
    if('K' in sep_chunk[3]):
        no_of_following = int(no_of_following * 1000)
    elif('M' in sep_chunk[3]):
        no_of_following = int(no_of_following * 1000000)
    else:
        no_of_following = int(no_of_following)
    
    name = sep_chunk[4]
    if(len(sep_chunk) > 5):
        type_of_page = sep_chunk[5]
        bio = "\n".join(sep_chunk[6:])
    else:
        type_of_page = "Unknown"
        bio = ""
    
    # print(username, no_of_posts, no_of_followers, no_of_following, name, type_of_page, bio, sep="\n")
    
    return {
        "username": username,
        "no_of_posts": no_of_posts,
        "no_of_followers": no_of_followers,
        "no_of_following": no_of_following,
        "name": name,
        "type_of_page": type_of_page,
        "bio": bio
    }

# %%
all_chunks = []
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)

# print(all_chunks)
import json

s = json.dumps(all_chunks, indent=4)
print(s)
# Out:
# [
#     {
#         "username": "techie_koramangala",
#         "no_of_posts": 420,
#         "no_of_followers": 9800,
#         "no_of_following": 310,
#         "name": "Arjun M.",
#         "type_of_page": "Software Engineer",
#         "bio": "\ud83d\udcbb Full-stack @ SaaS startup\n\u2615 Working from cafes in Koramangala\ngithub.com/arjunmakes"
#     },
#     {
#         "username": "blrcoder_girl",
#         "no_of_posts": 150,
#         "no_of_followers": 6300,
#         "no_of_following": 120,
#         "name": "Riya Codes",
#         "type_of_page": "Tech Creator",
#         "bio": "\ud83d\udc69\u200d\ud83d\udcbb Python | ML | Roadmaps\n\ud83c\udfa5 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes"
#     },
#     {
#         "username": "hsr_startup_stories",
#         "no_of_posts": 980,
#         "no_of_followers": 22400,
#         "no_of_following": 95,
#         "name": "Startup Stories HSR",
#         "type_of_page": "Media",
# ...

# %% [markdown]
# Who has maximum posts
# let write code to fiind max posts

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_post = chunk
print(chunk_with_max_post)
# Out:
# {'username': 'startuphub_blr', 'no_of_posts': 2300, 'no_of_followers': 45000, 'no_of_following': 120, 'name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %% [markdown]
# Who has maximum follower
# let write code to find max follower

# %%
max_follower = 0
for chunk in all_chunks:
    if(max_follower < chunk['no_of_followers']):
        max_follower = chunk['no_of_followers']
        max_no_of_follower = chunk

print(max_no_of_follower)
# Out:
# {'username': '_anujsinghal', 'no_of_posts': 1785, 'no_of_followers': 681000, 'no_of_following': 248, 'name': 'Anuj Singhal', 'type_of_page': 'Digital creator', 'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %% [markdown]
# Who has maximum following
# let write code to find max following

# %%
max_following = 0
for chunk in all_chunks:
    if(max_following < chunk['no_of_following']):
        max_following = chunk['no_of_following']
        max_no_of_following = chunk

print(max_no_of_following)
# Out:
# {'username': 'bangalore_tech_bro', 'no_of_posts': 402, 'no_of_followers': 12500, 'no_of_following': 890, 'name': 'Rahul | HSR Hustler', 'type_of_page': 'Entrepreneur', 'bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}

# %% [markdown]
# Howw many categories
# let write code to find categories

# %%
for chunk in all_chunks:
    if chunk['type_of_page'] == "Unknown":
        chunk['type_of_page'] = "Hello world"
    print(chunk['type_of_page'])
# Out:
# Software Engineer
# Tech Creator
# Media
# Engineer
# Cafe Explorer
# Media
# Founder
# Backend Developer
# Media
# Frontend Dev
# Lifestyle
# Food & Drink
# Community
# Full-stack Dev
# Community
# Media
# Blog
# Community
# Artist + Coder
# Product Manager
# Community
# Recruiter
# Developer
# Design
# Cafe Nerd
# Engineer
# Media
# Media
# Blog
# Tech Creator
# Lifestyle
# Community
# Media
# Education
# Developer
# Coder
# Lifestyle
# Community
# Education
# Community
# Comedy
# Design
# Data Science
# Data Scientist
# Education
# Community
# Nonprofit organization
# Digital creator
# Blogger
# Entrepreneur
# Public Figure
# Media
# Food & Drink
# Investor
# Community
# Personal Blog
# Media
# Personal Blog
# Community
# Community
# Tech
# Community
# Media
# Educator
# Community
# Community
# Community
# Blog
# Tech
# Personal Blog
# Community
# Community
# Community
# Community
# Blog
# Community
# Public Figure
# Community
# Personal Blog
# Community
# Blog
# Community
# ...

# %%
categories = set()
for chunk in all_chunks:
    if chunk['type_of_page'] == "Unknown":
        chunk['type_of_page'] = "Hello world"
    categories.add(chunk['type_of_page'])
print(categories, len(categories))
# Out:
# {'Software Engineer', 'Coder', 'Food & Drink', 'Media', 'Backend Developer', 'Digital creator', 'Nonprofit organization', 'Personal Blog', 'Cafe Explorer', 'Investor', 'Tech Creator', 'Engineer', 'Cafe Nerd', 'Public Figure', 'Lifestyle', 'Data Scientist', 'Artist + Coder', 'Writer', 'Blog', 'Tech', 'Data Science', 'Entrepreneur', 'Frontend Dev', 'Design', 'Product Manager', 'Comedy', 'Developer', 'Educator', 'Education', 'Blogger', 'Community', 'Recruiter', 'Founder', 'Full-stack Dev'} 34
