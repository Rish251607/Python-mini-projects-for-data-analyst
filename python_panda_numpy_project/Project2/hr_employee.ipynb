# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("HR-Employee_data.csv",encoding="latin1")
# df.info()

# %%
df.isnull().sum()
# Out:
# ï»¿Age                      0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns        # column names
# Out:
# Index(['ï»¿Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='str')

# %%
df.info()         # data types
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ï»¿Age                    1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   str
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#             ï»¿Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df['MonthlyIncome']
# Out:
# 0       5993
# 1       5130
# 2       2090
# 3       2909
# 4       3468
#         ...
# 1465    2571
# 1466    9991
# 1467    6142
# 1468    5390
# 1469    4404
# Name: MonthlyIncome, Length: 1470, dtype: int64

# %%
salary = df["MonthlyIncome"]

# %%
total = np.sum(salary)
total
# Out:
# np.int64(9559309)

# %%
np.mean(salary)
# Out:
# np.float64(6502.931292517007)

# %%
np.median(salary)
# Out:
# np.float64(4919.0)

# %%
np.percentile(salary, 25)
# Out:
# np.float64(2911.0)

# %%
np.percentile(salary, 75)
# Out:
# np.float64(8379.0)

# %%
plt.hist(salary, bins=20)
plt.xlabel("Monthly Income")
plt.ylabel("Number of Employees")
plt.title("Salary Distribution")
plt.show()

# %%
plt.boxplot(salary)
plt.title("Salary Boxplot")
plt.show()

# %%
df["PerformanceRating"].value_counts()
# Out:
# PerformanceRating
# 3    1244
# 4     226
# Name: count, dtype: int64

# %%
df.groupby("PerformanceRating")["MonthlyIncome"].mean()
# Out:
# PerformanceRating
# 3    6537.274116
# 4    6313.893805
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby("Department")["MonthlyIncome"].mean().sort_values(ascending=False)
# Out:
# Department
# Sales                     6959.172646
# Human Resources           6654.507937
# Research & Development    6281.252862
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby("Attrition")["MonthlyIncome"].mean()
# Out:
# Attrition
# No     6832.739659
# Yes    4787.092827
# Name: MonthlyIncome, dtype: float64

# %%
high = df[df["PerformanceRating"] == 4]
low = df[df["PerformanceRating"] == 3]

np.mean(high["MonthlyIncome"])
# Out:
# np.float64(6313.8938053097345)

# %%
np.mean(low["MonthlyIncome"])
# Out:
# np.float64(6537.2741157556275)

# %%
df.groupby("YearsAtCompany")["MonthlyIncome"].mean()
# Out:
# YearsAtCompany
# 0      4113.500000
# 1      4681.304094
# 2      4953.511811
# 3      5079.000000
# 4      5109.872727
# 5      5694.719388
# 6      5524.052632
# 7      6745.322222
# 8      6415.125000
# 9      7202.597561
# 10     6762.100000
# 11     6435.718750
# 12     8675.142857
# 13     8016.666667
# 14     9781.833333
# 15     6942.200000
# 16     9622.666667
# 17     8242.444444
# 18    10460.000000
# 19    12118.090909
# 20    12148.148148
# 21    15879.214286
# 22    16195.200000
# 23    11842.000000
# 24    15140.166667
# 25    16478.000000
# 26    14692.500000
# 27    17893.000000
# 29    19706.500000
# 30    11245.000000
# 31    18890.666667
# 32    17485.333333
# 33    15367.800000
# 34    16856.000000
# 36    19315.500000
# 37    13872.000000
# 40    10312.000000
# Name: MonthlyIncome, dtype: float64
