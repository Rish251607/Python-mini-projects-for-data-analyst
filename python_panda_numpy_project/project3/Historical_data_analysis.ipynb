# %%
# !pip install yfinance

# %%
import yfinance as yf

ticker = "AAPL"       # stock symbol you want
start_date = "2016-01-01"
end_date = "2025-12-31"

data = yf.download(ticker, start=start_date, end=end_date)
data.to_csv(f"{ticker}_historical.csv")
print("Saved:", f"{ticker}_historical.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Saved: AAPL_historical.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("AAPL_historical.csv")
data
# Out:
#            Price               Close                High                 Low  \
# 0         Ticker                AAPL                AAPL                AAPL
# 1           Date                 NaN                 NaN                 NaN
# 2     2016-01-04  23.730947494506836  23.735453620243067  22.976332980529655
# 3     2016-01-05  23.136266708374023  23.843577233061005  23.068690287724074
# 4     2016-01-06  22.683490753173828  23.059673099076566   22.49652782994531
# ...          ...                 ...                 ...                 ...
# 2510  2025-12-23   272.1053771972656   272.2452609569047  269.30800689497966
# 2511  2025-12-24  273.55401611328125  275.17249671786806   271.9455359163183
# 2512  2025-12-26   273.1444091796875   275.1125687682936      272.6049054553
# 2513  2025-12-29  273.50408935546875  274.10350406329195   272.0954038139857
# 2514  2025-12-30     272.82470703125  273.82377221524894  272.02546707967076
#
#                     Open     Volume
# ...

# %%
data.isnull().sum()
# Out:
# Price     0
# Close     1
# High      1
# Low       1
# Open      1
# Volume    1
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   2515 non-null   str
#  1   Close   2514 non-null   str
#  2   High    2514 non-null   str
#  3   Low     2514 non-null   str
#  4   Open    2514 non-null   str
#  5   Volume  2514 non-null   str
# dtypes: str(6)
# memory usage: 118.0 KB

# %%
data.head()
# Out:
#         Price               Close                High                 Low  \
# 0      Ticker                AAPL                AAPL                AAPL
# 1        Date                 NaN                 NaN                 NaN
# 2  2016-01-04  23.730947494506836  23.735453620243067  22.976332980529655
# 3  2016-01-05  23.136266708374023  23.843577233061005  23.068690287724074
# 4  2016-01-06  22.683490753173828  23.059673099076566   22.49652782994531
#
#                  Open     Volume
# 0                AAPL       AAPL
# 1                 NaN        NaN
# 2  23.113740599566555  270597600
# 3  23.821051759511022  223164000
# 4  22.651954755589113  273829600

# %%
df = pd.read_csv("AAPL_historical.csv", skiprows=2)

# %%
df
# Out:
#             Date  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0     2016-01-04   23.730947   23.735454   22.976333   23.113741   270597600
# 1     2016-01-05   23.136267   23.843577   23.068690   23.821052   223164000
# 2     2016-01-06   22.683491   23.059673   22.496528   22.651955   273829600
# 3     2016-01-07   21.726145   22.555095   21.721640   22.228471   324377600
# 4     2016-01-08   21.841036   22.325341   21.795985   22.199197   283192000
# ...          ...         ...         ...         ...         ...         ...
# 2508  2025-12-23  272.105377  272.245261  269.308007  270.586809    29642000
# 2509  2025-12-24  273.554016  275.172497  271.945536  272.085389    17910600
# 2510  2025-12-26  273.144409  275.112569  272.604905  273.903708    21521800
# 2511  2025-12-29  273.504089  274.103504  272.095404  272.435082    23715200
# 2512  2025-12-30  272.824707  273.823772  272.025467  272.554970    22139600
#
# [2513 rows x 6 columns]

# %%
df.head()
# Out:
#          Date  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0  2016-01-04   23.730947   23.735454   22.976333   23.113741   270597600
# 1  2016-01-05   23.136267   23.843577   23.068690   23.821052   223164000
# 2  2016-01-06   22.683491   23.059673   22.496528   22.651955   273829600
# 3  2016-01-07   21.726145   22.555095   21.721640   22.228471   324377600
# 4  2016-01-08   21.841036   22.325341   21.795985   22.199197   283192000

# %%
df.columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2513 entries, 0 to 2512
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2513 non-null   str
#  1   Close   2513 non-null   float64
#  2   High    2513 non-null   float64
#  3   Low     2513 non-null   float64
#  4   Open    2513 non-null   float64
#  5   Volume  2513 non-null   int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 117.9 KB

# %%
df
# Out:
#             Date       Close        High         Low        Open     Volume
# 0     2016-01-04   23.730947   23.735454   22.976333   23.113741  270597600
# 1     2016-01-05   23.136267   23.843577   23.068690   23.821052  223164000
# 2     2016-01-06   22.683491   23.059673   22.496528   22.651955  273829600
# 3     2016-01-07   21.726145   22.555095   21.721640   22.228471  324377600
# 4     2016-01-08   21.841036   22.325341   21.795985   22.199197  283192000
# ...          ...         ...         ...         ...         ...        ...
# 2508  2025-12-23  272.105377  272.245261  269.308007  270.586809   29642000
# 2509  2025-12-24  273.554016  275.172497  271.945536  272.085389   17910600
# 2510  2025-12-26  273.144409  275.112569  272.604905  273.903708   21521800
# 2511  2025-12-29  273.504089  274.103504  272.095404  272.435082   23715200
# 2512  2025-12-30  272.824707  273.823772  272.025467  272.554970   22139600
#
# [2513 rows x 6 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 2513 entries, 2016-01-04 to 2025-12-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2513 non-null   float64
#  1   High    2513 non-null   float64
#  2   Low     2513 non-null   float64
#  3   Open    2513 non-null   float64
#  4   Volume  2513 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 117.8 KB
#                 Close       High        Low       Open     Volume
# Date
# 2016-01-04  23.730947  23.735454  22.976333  23.113741  270597600
# 2016-01-05  23.136267  23.843577  23.068690  23.821052  223164000
# 2016-01-06  22.683491  23.059673  22.496528  22.651955  273829600
# 2016-01-07  21.726145  22.555095  21.721640  22.228471  324377600
# 2016-01-08  21.841036  22.325341  21.795985  22.199197  283192000

# %%
df.isnull().sum()
# Out:
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
df
# Out:
#                  Close        High         Low        Open     Volume
# Date
# 2016-01-04   23.730947   23.735454   22.976333   23.113741  270597600
# 2016-01-05   23.136267   23.843577   23.068690   23.821052  223164000
# 2016-01-06   22.683491   23.059673   22.496528   22.651955  273829600
# 2016-01-07   21.726145   22.555095   21.721640   22.228471  324377600
# 2016-01-08   21.841036   22.325341   21.795985   22.199197  283192000
# ...                ...         ...         ...         ...        ...
# 2025-12-23  272.105377  272.245261  269.308007  270.586809   29642000
# 2025-12-24  273.554016  275.172497  271.945536  272.085389   17910600
# 2025-12-26  273.144409  275.112569  272.604905  273.903708   21521800
# 2025-12-29  273.504089  274.103504  272.095404  272.435082   23715200
# 2025-12-30  272.824707  273.823772  272.025467  272.554970   22139600
#
# [2513 rows x 5 columns]

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Close'])
plt.title("Closing Price Trend")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
df.head()
# Out:
#                 Close       High        Low       Open     Volume
# Date
# 2016-01-04  23.730947  23.735454  22.976333  23.113741  270597600
# 2016-01-05  23.136267  23.843577  23.068690  23.821052  223164000
# 2016-01-06  22.683491  23.059673  22.496528  22.651955  273829600
# 2016-01-07  21.726145  22.555095  21.721640  22.228471  324377600
# 2016-01-08  21.841036  22.325341  21.795985  22.199197  283192000

# %%
df['MA20'] = df['Close'].rolling(window=20).mean()

# %%
df['MA20']
# Out:
# Date
# 2016-01-04           NaN
# 2016-01-05           NaN
# 2016-01-06           NaN
# 2016-01-07           NaN
# 2016-01-08           NaN
#                  ...
# 2025-12-23    277.050758
# 2025-12-24    276.892905
# 2025-12-26    276.685599
# 2025-12-29    276.431337
# 2025-12-30    275.930804
# Name: MA20, Length: 2513, dtype: float64

# %%
df['MA50'] = df['Close'].rolling(window=50).mean()
df['MA50']
# Out:
# Date
# 2016-01-04           NaN
# 2016-01-05           NaN
# 2016-01-06           NaN
# 2016-01-07           NaN
# 2016-01-08           NaN
#                  ...
# 2025-12-23    270.176154
# 2025-12-24    270.701262
# 2025-12-26    271.186837
# 2025-12-29    271.717334
# 2025-12-30    272.137628
# Name: MA50, Length: 2513, dtype: float64

# %%
plt.figure(figsize=(12,6))

plt.plot(df['Close'], label='Closing Price')
plt.plot(df['MA20'], label='20-Day MA')
plt.plot(df['MA50'], label='50-Day MA')

plt.legend()
plt.title("Stock Price with Moving Averages")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
df[['Close','MA20','MA50']].plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'], label='Closing Price')
plt.plot(df['MA20'], label='20 Day MA')
plt.plot(df['MA50'], label='50 Day MA')
plt.legend()
plt.title("AAPL Stock Price Trend")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()
